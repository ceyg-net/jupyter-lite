-- %% [markdown]
-- ![Recipes Example Schema.jpg](attachment:43af2ec8-7fb7-4bf5-a67e-755c1982ce86.jpg)

-- %%
%LOAD Recipes.sqlite

-- %%
SELECT name FROM sqlite_master WHERE type='table';
-- Out:
-- +--------------------+
-- | name               |
-- +--------------------+
-- | Ingredient_Classes |
-- +--------------------+
-- | Measurements       |
-- +--------------------+
-- | Ingredients        |
-- +--------------------+
-- | Recipe_Classes     |
-- +--------------------+
-- | Recipes            |
-- +--------------------+
-- | Recipe_Ingredients |
-- +--------------------+
